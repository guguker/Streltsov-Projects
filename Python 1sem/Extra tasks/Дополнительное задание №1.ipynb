# %% [markdown]
# <a href="https://colab.research.google.com/github/guguker/University/blob/main/Extra%20tasks/%D0%94%D0%BE%D0%BF%D0%BE%D0%BB%D0%BD%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D0%B5%20%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5%20%E2%84%961.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Без имени.png](data:image/png;base64,...)

# %%
import random

answ, cnt = random.randint(0, 100), 0
print(f'Компьютер загадал число! {answ}')

while True:

  us_answ = input('Введите число : ')

  if (us_answ.lower() == 'выход'):
    break

  elif not (us_answ.isdigit()):
    print('Ошибка!')
    continue

  us_answ = int(us_answ)
  cnt += 1

  if answ < us_answ:
    print('Ваше число больше загаданного. Попробуйте ещё раз :)')
  elif answ > us_answ:
    print('Ваше число меньше загаданного. Попробуйте ещё раз :)')
  else:
    print('Вы угадали число!')
    print(f'Вам потребовалось {cnt} попыток.')
    break
# Out:
# Компьютер загадал число! 70
# Введите число : 50
# Ваше число меньше загаданного. Попробуйте ещё раз :)
# Введите число : 80
# Ваше число больше загаданного. Попробуйте ещё раз :)
# Введите число : jfjffj
# Ошибка!
# Введите число : 70
# Вы угадали число!
# Вам потребовалось 3 попыток.
